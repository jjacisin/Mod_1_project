# %%
import pandas as pd
records = pd.read_json("https://data.cityofnewyork.us/resource/7x9x-zpz6.json?$limit=300000")

# %%
crime_data = records.to_dict('records')
crime_data
# Out:
# [{'addr_pct_cd': 19,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-06-07T00:00:00.000',
#   'cmplnt_fr_tm': '13:20:00',
#   'cmplnt_num': 568680571,
#   'cmplnt_to_dt': '2018-06-07T00:00:00.000',
#   'cmplnt_to_tm': '13:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 105,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.955834874, 40.779163]},
#   'latitude': 40.779163,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.955834874,
#   'ofns_desc': 'ROBBERY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 384.0,
#   'pd_desc': 'ROBBERY,POCKETBOOK/CARRIED BAG',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-07T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 996482.0,
#   'y_coord_cd': 223147.0},
#  {'addr_pct_cd': 40,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-06-16T00:00:00.000',
#   'cmplnt_fr_tm': '18:00:00',
#   'cmplnt_num': 740647006,
#   'cmplnt_to_dt': '2018-06-17T00:00:00.000',
#   'cmplnt_to_tm': '05:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.916571116, 40.822837337]},
#   'latitude': 40.822837337,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.916571116,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 421.0,
#   'pd_desc': 'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-17T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1007341.0,
#   'y_coord_cd': 239067.0},
#  {'addr_pct_cd': 6,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-04-23T00:00:00.000',
#   'cmplnt_fr_tm': '15:20:00',
#   'cmplnt_num': 966432005,
#   'cmplnt_to_dt': '2018-04-23T00:00:00.000',
#   'cmplnt_to_tm': '15:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.993870805, 40.735667088]},
#   'latitude': 40.735667088,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.993870805,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 338.0,
#   'pd_desc': 'LARCENY,PETIT FROM BUILDING,UN',
#   'prem_typ_desc': 'DRUG STORE',
#   'rpt_dt': '2018-04-23T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 985949.0,
#   'y_coord_cd': 207297.0},
#  {'addr_pct_cd': 78,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-05T00:00:00.000',
#   'cmplnt_fr_tm': '19:50:00',
#   'cmplnt_num': 619611663,
#   'cmplnt_to_dt': '2018-02-05T00:00:00.000',
#   'cmplnt_to_tm': '20:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.97775121, 40.684461543]},
#   'latitude': 40.684461543,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.97775121,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'CHAIN STORE',
#   'rpt_dt': '2018-02-05T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '18-24',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 990421.0,
#   'y_coord_cd': 188642.0},
#  {'addr_pct_cd': 90,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-16T00:00:00.000',
#   'cmplnt_fr_tm': '13:30:00',
#   'cmplnt_num': 703493598,
#   'cmplnt_to_dt': '2018-02-17T00:00:00.000',
#   'cmplnt_to_tm': '20:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 107,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.958154327, 40.708050116]},
#   'latitude': 40.708050116,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.958154327,
#   'ofns_desc': 'BURGLARY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 234.0,
#   'pd_desc': 'BURGLARY,UNKNOWN TIME',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-02-18T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 995852.0,
#   'y_coord_cd': 197238.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-04-14T00:00:00.000',
#   'cmplnt_fr_tm': '20:40:00',
#   'cmplnt_num': 840976601,
#   'cmplnt_to_dt': '2018-04-14T00:00:00.000',
#   'cmplnt_to_tm': '20:51:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.087471423, 40.638812184]},
#   'latitude': 40.638812184,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -74.087471423,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'CHAIN STORE',
#   'rpt_dt': '2018-04-14T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 959974.0,
#   'y_coord_cd': 172022.0},
#  {'addr_pct_cd': 81,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-28T00:00:00.000',
#   'cmplnt_fr_tm': '19:00:00',
#   'cmplnt_num': 861801988,
#   'cmplnt_to_dt': '2018-03-01T00:00:00.000',
#   'cmplnt_to_tm': '08:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.92586563, 40.68194756]},
#   'latitude': 40.68194756,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.92586563,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-03-01T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1004812.0,
#   'y_coord_cd': 187734.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-01-11T00:00:00.000',
#   'cmplnt_fr_tm': '23:00:00',
#   'cmplnt_num': 143415880,
#   'cmplnt_to_dt': '2018-01-11T00:00:00.000',
#   'cmplnt_to_tm': '23:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.083049279, 40.614782068]},
#   'latitude': 40.614782068,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -74.083049279,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 321.0,
#   'pd_desc': 'LARCENY,PETIT FROM AUTO',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-01-12T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'ASIAN/PAC.ISL',
#   'vic_sex': 'M',
#   'x_coord_cd': 961193.0,
#   'y_coord_cd': 163266.0},
#  {'addr_pct_cd': 122,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-04-10T00:00:00.000',
#   'cmplnt_fr_tm': '07:50:00',
#   'cmplnt_num': 766362606,
#   'cmplnt_to_dt': '2018-04-10T00:00:00.000',
#   'cmplnt_to_tm': '08:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.136692249, 40.549991806]},
#   'latitude': 40.549991806,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -74.136692249,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 638.0,
#   'pd_desc': 'HARASSMENT,SUBD 3,4,5',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-04-10T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '<18',
#   'vic_race': 'ASIAN/PAC.ISL',
#   'vic_sex': 'M',
#   'x_coord_cd': 946263.0,
#   'y_coord_cd': 139680.0},
#  {'addr_pct_cd': 14,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-03-20T00:00:00.000',
#   'cmplnt_fr_tm': '20:44:00',
#   'cmplnt_num': 753989032,
#   'cmplnt_to_dt': '2018-03-20T00:00:00.000',
#   'cmplnt_to_tm': '20:44:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.989282176, 40.750430768]},
#   'latitude': 40.750430768,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.989282176,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'DEPARTMENT STORE',
#   'rpt_dt': '2018-03-20T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 987220.0,
#   'y_coord_cd': 212676.0},
#  {'addr_pct_cd': 18,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-05-11T00:00:00.000',
#   'cmplnt_fr_tm': '16:00:00',
#   'cmplnt_num': 333355172,
#   'cmplnt_to_dt': '2018-05-25T00:00:00.000',
#   'cmplnt_to_tm': '12:11:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.988084533, 40.767222999]},
#   'latitude': 40.767222999,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.988084533,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 438.0,
#   'pd_desc': 'LARCENY,GRAND FROM BUILDING (NON-RESIDENCE) UNATTENDED',
#   'prem_typ_desc': 'COMMERCIAL BUILDING',
#   'rpt_dt': '2018-05-30T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'WHITE',
#   'vic_sex': 'F',
#   'x_coord_cd': 987551.0,
#   'y_coord_cd': 218794.0},
#  {'addr_pct_cd': 32,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-05-06T00:00:00.000',
#   'cmplnt_fr_tm': '14:00:00',
#   'cmplnt_num': 714761216,
#   'cmplnt_to_dt': '2018-05-06T00:00:00.000',
#   'cmplnt_to_tm': '14:23:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 106,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.941975579, 40.809628853]},
#   'latitude': 40.809628853,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.941975579,
#   'ofns_desc': 'FELONY ASSAULT',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 109.0,
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-05-06T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1000313.0,
#   'y_coord_cd': 234249.0},
#  {'addr_pct_cd': 60,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-01-13T00:00:00.000',
#   'cmplnt_fr_tm': '15:45:00',
#   'cmplnt_num': 810428243,
#   'cmplnt_to_dt': '2018-01-13T00:00:00.000',
#   'cmplnt_to_tm': '16:15:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': 252.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.978275632, 40.590974199]},
#   'latitude': 40.590974199,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.978275632,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 338.0,
#   'pd_desc': 'LARCENY,PETIT FROM BUILDING,UN',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-01-23T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 990284.0,
#   'y_coord_cd': 154582.0},
#  {'addr_pct_cd': 32,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-04-04T00:00:00.000',
#   'cmplnt_fr_tm': '20:00:00',
#   'cmplnt_num': 746225125,
#   'cmplnt_to_dt': '2018-04-04T00:00:00.000',
#   'cmplnt_to_tm': '20:10:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': 741.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.947576544, 40.811986508]},
#   'latitude': 40.811986508,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'OPPOSITE OF',
#   'longitude': -73.947576544,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-04-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'ASIAN/PAC.ISL',
#   'vic_sex': 'F',
#   'x_coord_cd': 998762.0,
#   'y_coord_cd': 235107.0},
#  {'addr_pct_cd': 52,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-03-10T00:00:00.000',
#   'cmplnt_fr_tm': '15:00:00',
#   'cmplnt_num': 738762711,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.911283905, 40.861701225]},
#   'latitude': 40.861701225,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.911283905,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 258.0,
#   'pd_desc': 'CRIMINAL MISCHIEF 4TH, GRAFFIT',
#   'prem_typ_desc': 'STORE UNCLASSIFIED',
#   'rpt_dt': '2018-03-10T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'E',
#   'x_coord_cd': 1008790.0,
#   'y_coord_cd': 253228.0},
#  {'addr_pct_cd': 25,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-06-22T00:00:00.000',
#   'cmplnt_fr_tm': '13:00:00',
#   'cmplnt_num': 961909419,
#   'cmplnt_to_dt': '2018-06-22T00:00:00.000',
#   'cmplnt_to_tm': '13:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.938030616, 40.802114486]},
#   'latitude': 40.802114486,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'OPPOSITE OF',
#   'longitude': -73.938030616,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': 'DR. RONALD E. MCNAIR PLAYGROUND',
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 339.0,
#   'pd_desc': 'LARCENY,PETIT FROM OPEN AREAS,',
#   'prem_typ_desc': 'PARK/PLAYGROUND',
#   'rpt_dt': '2018-06-22T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1001407.0,
#   'y_coord_cd': 231512.0},
#  {'addr_pct_cd': 61,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-28T00:00:00.000',
#   'cmplnt_fr_tm': '10:00:00',
#   'cmplnt_num': 922772355,
#   'cmplnt_to_dt': '2018-02-28T00:00:00.000',
#   'cmplnt_to_tm': '10:05:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.941665052, 40.599258977]},
#   'latitude': 40.599258977,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.941665052,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 638.0,
#   'pd_desc': 'HARASSMENT,SUBD 3,4,5',
#   'prem_typ_desc': 'PUBLIC BUILDING',
#   'rpt_dt': '2018-02-28T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE',
#   'vic_sex': 'F',
#   'x_coord_cd': 1000450.0,
#   'y_coord_cd': 157605.0},
#  {'addr_pct_cd': 78,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_fr_tm': '00:10:00',
#   'cmplnt_num': 537085018,
#   'cmplnt_to_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_to_tm': '00:20:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.976702211, 40.683794356]},
#   'latitude': 40.683794356,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.976702211,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 638.0,
#   'pd_desc': 'HARASSMENT,SUBD 3,4,5',
#   'prem_typ_desc': 'CHAIN STORE',
#   'rpt_dt': '2018-01-28T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 990712.0,
#   'y_coord_cd': 188399.0},
#  {'addr_pct_cd': 83,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-06-04T00:00:00.000',
#   'cmplnt_fr_tm': '22:30:00',
#   'cmplnt_num': 779778728,
#   'cmplnt_to_dt': '2018-06-04T00:00:00.000',
#   'cmplnt_to_tm': '22:35:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.929064564, 40.701462152]},
#   'latitude': 40.701462152,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.929064564,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 259.0,
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-06-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE',
#   'vic_sex': 'F',
#   'x_coord_cd': 1003919.0,
#   'y_coord_cd': 194843.0},
#  {'addr_pct_cd': 32,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-01-16T00:00:00.000',
#   'cmplnt_fr_tm': '10:30:00',
#   'cmplnt_num': 692813797,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.943915089, 40.810038777]},
#   'latitude': 40.810038777,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.943915089,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 259.0,
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-01-16T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 999776.0,
#   'y_coord_cd': 234398.0},
#  {'addr_pct_cd': 26,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2017-12-15T00:00:00.000',
#   'cmplnt_fr_tm': '09:01:00',
#   'cmplnt_num': 910602783,
#   'cmplnt_to_dt': '2018-01-24T00:00:00.000',
#   'cmplnt_to_tm': '11:48:00',
#   'crm_atpt_cptd_cd': 'ATTEMPTED',
#   'hadevelopt': nan,
#   'housing_psa': 720.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.955169978, 40.812115968]},
#   'latitude': 40.812115968,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.955169978,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 430.0,
#   'pd_desc': 'LARCENY,GRAND BY BANK ACCT COMPROMISE-UNCLASSIFIED',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-01-24T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 996660.0,
#   'y_coord_cd': 235153.0},
#  {'addr_pct_cd': 75,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-01-23T00:00:00.000',
#   'cmplnt_fr_tm': '02:30:00',
#   'cmplnt_num': 439017805,
#   'cmplnt_to_dt': '2018-01-23T00:00:00.000',
#   'cmplnt_to_tm': '10:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.878437318, 40.649334913]},
#   'latitude': 40.649334913,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.878437318,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-01-23T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1017983.0,
#   'y_coord_cd': 175867.0},
#  {'addr_pct_cd': 41,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_fr_tm': '00:40:00',
#   'cmplnt_num': 731929404,
#   'cmplnt_to_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_to_tm': '00:45:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.887009956, 40.815673141]},
#   'latitude': 40.815673141,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.887009956,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 638.0,
#   'pd_desc': 'HARASSMENT,SUBD 3,4,5',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-01-28T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1015526.0,
#   'y_coord_cd': 236466.0},
#  {'addr_pct_cd': 25,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-01-17T00:00:00.000',
#   'cmplnt_fr_tm': '15:30:00',
#   'cmplnt_num': 864246704,
#   'cmplnt_to_dt': '2018-01-17T00:00:00.000',
#   'cmplnt_to_tm': '15:40:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 361,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.936541904, 40.802717516]},
#   'latitude': 40.802717516,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.936541904,
#   'ofns_desc': 'OFF. AGNST PUB ORD SENSBLTY &',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 639.0,
#   'pd_desc': 'AGGRAVATED HARASSMENT 2',
#   'prem_typ_desc': 'COMMERCIAL BUILDING',
#   'rpt_dt': '2018-01-17T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 1001819.0,
#   'y_coord_cd': 231732.0},
#  {'addr_pct_cd': 71,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-04-14T00:00:00.000',
#   'cmplnt_fr_tm': '22:00:00',
#   'cmplnt_num': 411804478,
#   'cmplnt_to_dt': '2018-04-17T00:00:00.000',
#   'cmplnt_to_tm': '07:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.961088182, 40.668482524]},
#   'latitude': 40.668482524,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.961088182,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 349.0,
#   'pd_desc': 'LARCENY,PETIT OF LICENSE PLATE',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-04-17T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 995045.0,
#   'y_coord_cd': 182822.0},
#  {'addr_pct_cd': 1,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-05-13T00:00:00.000',
#   'cmplnt_fr_tm': '10:30:00',
#   'cmplnt_num': 378134157,
#   'cmplnt_to_dt': '2018-05-13T00:00:00.000',
#   'cmplnt_to_tm': '10:33:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 343,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.008982852, 40.709937533]},
#   'latitude': 40.709937533,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -74.008982852,
#   'ofns_desc': 'OTHER OFFENSES RELATED TO THEF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 478.0,
#   'pd_desc': 'THEFT OF SERVICES, UNCLASSIFIE',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-05-13T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'WHITE',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'AMER IND',
#   'vic_sex': 'M',
#   'x_coord_cd': 981760.0,
#   'y_coord_cd': 197923.0},
#  {'addr_pct_cd': 75,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-10T00:00:00.000',
#   'cmplnt_fr_tm': '19:00:00',
#   'cmplnt_num': 328581972,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 121,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.883270323, 40.682052218]},
#   'latitude': 40.682052218,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.883270323,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 269.0,
#   'pd_desc': 'MISCHIEF,CRIMINAL,    UNCL 2ND',
#   'prem_typ_desc': 'RESIDENCE-HOUSE',
#   'rpt_dt': '2018-02-13T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '65+',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'F',
#   'x_coord_cd': 1016626.0,
#   'y_coord_cd': 187785.0},
#  {'addr_pct_cd': 114,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-01-17T00:00:00.000',
#   'cmplnt_fr_tm': '15:00:00',
#   'cmplnt_num': 242732604,
#   'cmplnt_to_dt': '2018-01-21T00:00:00.000',
#   'cmplnt_to_tm': '16:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 121,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.91550818, 40.769306087]},
#   'latitude': 40.769306087,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.91550818,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS NORTH',
#   'pd_cd': 267.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 3 & 2, OF M',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-01-21T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1007654.0,
#   'y_coord_cd': 219564.0},
#  {'addr_pct_cd': 75,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-05-13T00:00:00.000',
#   'cmplnt_fr_tm': '02:01:00',
#   'cmplnt_num': 207448066,
#   'cmplnt_to_dt': '2018-05-13T00:00:00.000',
#   'cmplnt_to_tm': '02:17:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 121,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.891035622, 40.662753062]},
#   'latitude': 40.662753062,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.891035622,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 269.0,
#   'pd_desc': 'MISCHIEF,CRIMINAL,    UNCL 2ND',
#   'prem_typ_desc': 'DRY CLEANER/LAUNDRY',
#   'rpt_dt': '2018-05-13T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 1014481.0,
#   'y_coord_cd': 180751.0},
#  {'addr_pct_cd': 45,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-03-11T00:00:00.000',
#   'cmplnt_fr_tm': '09:44:00',
#   'cmplnt_num': 733765612,
#   'cmplnt_to_dt': '2018-03-11T00:00:00.000',
#   'cmplnt_to_tm': '09:50:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 107,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.82166043, 40.846279289]},
#   'latitude': 40.846279289,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.82166043,
#   'ofns_desc': 'BURGLARY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 211.0,
#   'pd_desc': 'BURGLARY,COMMERCIAL,DAY',
#   'prem_typ_desc': 'SMALL MERCHANT',
#   'rpt_dt': '2018-03-20T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'WHITE',
#   'vic_sex': 'D',
#   'x_coord_cd': 1033592.0,
#   'y_coord_cd': 247647.0},
#  {'addr_pct_cd': 103,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-05-24T00:00:00.000',
#   'cmplnt_fr_tm': '19:20:00',
#   'cmplnt_num': 747285027,
#   'cmplnt_to_dt': '2018-05-24T00:00:00.000',
#   'cmplnt_to_tm': '19:25:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.782288865, 40.698289052]},
#   'latitude': 40.698289052,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.782288865,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 637.0,
#   'pd_desc': 'HARASSMENT,SUBD 1,CIVILIAN',
#   'prem_typ_desc': 'OTHER',
#   'rpt_dt': '2018-05-24T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '18-24',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1044619.0,
#   'y_coord_cd': 193754.0},
#  {'addr_pct_cd': 32,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-06-07T00:00:00.000',
#   'cmplnt_fr_tm': '01:00:00',
#   'cmplnt_num': 992708044,
#   'cmplnt_to_dt': '2018-06-07T00:00:00.000',
#   'cmplnt_to_tm': '01:20:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 361,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.9508605, 40.811751909]},
#   'latitude': 40.811751909,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.9508605,
#   'ofns_desc': 'OFF. AGNST PUB ORD SENSBLTY &',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 639.0,
#   'pd_desc': 'AGGRAVATED HARASSMENT 2',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-06-07T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 997853.0,
#   'y_coord_cd': 235021.0},
#  {'addr_pct_cd': 68,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-06-27T00:00:00.000',
#   'cmplnt_fr_tm': '22:00:00',
#   'cmplnt_num': 208705258,
#   'cmplnt_to_dt': '2018-06-27T00:00:00.000',
#   'cmplnt_to_tm': '22:15:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 678,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.036214078, 40.614136636]},
#   'latitude': 40.614136636,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -74.036214078,
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 201.0,
#   'pd_desc': 'TRESPASS 4,CRIMINAL SUB 2',
#   'prem_typ_desc': 'RESIDENCE-HOUSE',
#   'rpt_dt': '2018-06-29T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'WHITE',
#   'vic_sex': 'F',
#   'x_coord_cd': 974196.0,
#   'y_coord_cd': 163022.0},
#  {'addr_pct_cd': 52,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-02-11T00:00:00.000',
#   'cmplnt_fr_tm': '08:00:00',
#   'cmplnt_num': 475761400,
#   'cmplnt_to_dt': '2018-02-12T00:00:00.000',
#   'cmplnt_to_tm': '14:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.904390852, 40.865911578]},
#   'latitude': 40.865911578,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.904390852,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 321.0,
#   'pd_desc': 'LARCENY,PETIT FROM AUTO',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-02-12T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1010695.0,
#   'y_coord_cd': 254764.0},
#  {'addr_pct_cd': 25,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-04-23T00:00:00.000',
#   'cmplnt_fr_tm': '09:30:00',
#   'cmplnt_num': 369931754,
#   'cmplnt_to_dt': '2018-04-24T00:00:00.000',
#   'cmplnt_to_tm': '16:53:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.937882826, 40.809533401]},
#   'latitude': 40.809533401,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.937882826,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 357.0,
#   'pd_desc': 'LARCENY,PETIT OF VEHICLE ACCES',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-04-24T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1001446.0,
#   'y_coord_cd': 234215.0},
#  {'addr_pct_cd': 101,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-05-04T00:00:00.000',
#   'cmplnt_fr_tm': '17:19:00',
#   'cmplnt_num': 951932695,
#   'cmplnt_to_dt': '2018-05-04T00:00:00.000',
#   'cmplnt_to_tm': '18:18:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': 46468.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 126,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.772466409, 40.596462931]},
#   'latitude': 40.596462931,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.772466409,
#   'ofns_desc': 'MISCELLANEOUS PENAL LAW',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 198.0,
#   'pd_desc': 'CRIMINAL CONTEMPT 1',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-05-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 1047439.0,
#   'y_coord_cd': 156663.0},
#  {'addr_pct_cd': 103,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-05-19T00:00:00.000',
#   'cmplnt_fr_tm': '08:00:00',
#   'cmplnt_num': 867694585,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.797469119, 40.690823527]},
#   'latitude': 40.690823527,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.797469119,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 259.0,
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-05-19T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '18-24',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1040416.0,
#   'y_coord_cd': 191024.0},
#  {'addr_pct_cd': 41,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-02-06T00:00:00.000',
#   'cmplnt_fr_tm': '08:30:00',
#   'cmplnt_num': 831017283,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 106,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.895824354, 40.816087661]},
#   'latitude': 40.816087661,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.895824354,
#   'ofns_desc': 'FELONY ASSAULT',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 106.0,
#   'pd_desc': 'ASSAULT POLICE/PEACE OFFICER',
#   'prem_typ_desc': 'OTHER',
#   'rpt_dt': '2018-02-06T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1013086.0,
#   'y_coord_cd': 236614.0},
#  {'addr_pct_cd': 105,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-01-07T00:00:00.000',
#   'cmplnt_fr_tm': '10:30:00',
#   'cmplnt_num': 575210716,
#   'cmplnt_to_dt': '2018-01-07T00:00:00.000',
#   'cmplnt_to_tm': '10:40:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.731168383, 40.709947866]},
#   'latitude': 40.709947866,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.731168383,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 638.0,
#   'pd_desc': 'HARASSMENT,SUBD 3,4,5',
#   'prem_typ_desc': 'RESIDENCE-HOUSE',
#   'rpt_dt': '2018-01-07T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '45-64',
#   'susp_race': 'ASIAN/PAC.ISL',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'ASIAN/PAC.ISL',
#   'vic_sex': 'M',
#   'x_coord_cd': 1058781.0,
#   'y_coord_cd': 198041.0},
#  {'addr_pct_cd': 102,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '2018-03-27T00:00:00.000',
#   'cmplnt_fr_tm': '17:10:00',
#   'cmplnt_num': 632373006,
#   'cmplnt_to_dt': '2018-03-27T00:00:00.000',
#   'cmplnt_to_tm': '17:23:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 113,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.862308786, 40.685177302]},
#   'latitude': 40.685177302,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.862308786,
#   'ofns_desc': 'FORGERY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 729.0,
#   'pd_desc': 'FORGERY,ETC.,UNCLASSIFIED-FELO',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-03-27T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'E',
#   'x_coord_cd': 1022438.0,
#   'y_coord_cd': 188932.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-03-13T00:00:00.000',
#   'cmplnt_fr_tm': '17:30:00',
#   'cmplnt_num': 257025810,
#   'cmplnt_to_dt': '2018-03-13T00:00:00.000',
#   'cmplnt_to_tm': '17:35:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.078624185, 40.628355436]},
#   'latitude': 40.628355436,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'REAR OF',
#   'longitude': -74.078624185,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'RESIDENCE-HOUSE',
#   'rpt_dt': '2018-03-13T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 962426.0,
#   'y_coord_cd': 168210.0},
#  {'addr_pct_cd': 5,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2017-12-23T00:00:00.000',
#   'cmplnt_fr_tm': '00:01:00',
#   'cmplnt_num': 985244339,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.999334029, 40.722415566]},
#   'latitude': 40.722415566,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.999334029,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 424.0,
#   'pd_desc': 'LARCENY,GRAND BY CREDIT CARD ACCT COMPROMISE-EXISTING ACCT',
#   'prem_typ_desc': 'COMMERCIAL BUILDING',
#   'rpt_dt': '2018-03-14T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 984435.0,
#   'y_coord_cd': 202469.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-02-14T00:00:00.000',
#   'cmplnt_fr_tm': '13:50:00',
#   'cmplnt_num': 366321481,
#   'cmplnt_to_dt': '2018-02-14T00:00:00.000',
#   'cmplnt_to_tm': '13:58:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 344,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.083049279, 40.614782068]},
#   'latitude': 40.614782068,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -74.083049279,
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 101.0,
#   'pd_desc': 'ASSAULT 3',
#   'prem_typ_desc': 'PARK/PLAYGROUND',
#   'rpt_dt': '2018-02-14T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '18-24',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 961193.0,
#   'y_coord_cd': 163266.0},
#  {'addr_pct_cd': 81,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-03-28T00:00:00.000',
#   'cmplnt_fr_tm': '00:05:00',
#   'cmplnt_num': 869138428,
#   'cmplnt_to_dt': '2018-03-28T00:00:00.000',
#   'cmplnt_to_tm': '00:15:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. TRANSIT POLICE',
#   'jurisdiction_code': 1.0,
#   'ky_cd': 344,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.92905931, 40.679284397]},
#   'latitude': 40.679284397,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.92905931,
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 101.0,
#   'pd_desc': 'ASSAULT 3',
#   'prem_typ_desc': 'TRANSIT - NYC SUBWAY',
#   'rpt_dt': '2018-03-28T00:00:00.000',
#   'station_name': 'UTICA AVENUE',
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'F',
#   'transit_district': 33.0,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1003927.0,
#   'y_coord_cd': 186763.0},
#  {'addr_pct_cd': 84,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-02T00:00:00.000',
#   'cmplnt_fr_tm': '19:00:00',
#   'cmplnt_num': 532105700,
#   'cmplnt_to_dt': '2018-02-02T00:00:00.000',
#   'cmplnt_to_tm': '19:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.999543473, 40.693065804]},
#   'latitude': 40.693065804,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.999543473,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 420.0,
#   'pd_desc': 'LARCENY,GRAND BY OPEN/COMPROMISE CELL PHONE ACCT',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-03-03T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE',
#   'vic_sex': 'M',
#   'x_coord_cd': 984377.0,
#   'y_coord_cd': 191776.0},
#  {'addr_pct_cd': 44,
#   'boro_nm': 'BRONX',
# ...
#   'vic_sex': 'M',
#   'x_coord_cd': 983423.0,
#   'y_coord_cd': 209491.0},
#  {'addr_pct_cd': 45,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_fr_tm': '01:30:00',
#   'cmplnt_num': 599065921,
#   'cmplnt_to_dt': '2018-01-28T00:00:00.000',
#   'cmplnt_to_tm': '02:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': 'THROGGS NECK',
#   'housing_psa': 939.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 578,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.824055827, 40.820672004]},
#   'latitude': 40.820672004,
#   'law_cat_cd': 'VIOLATION',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.824055827,
#   'ofns_desc': 'HARRASSMENT 2',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 637.0,
#   'pd_desc': 'HARASSMENT,SUBD 1,CIVILIAN',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-01-28T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '45-64',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1032948.0,
#   'y_coord_cd': 238316.0},
#  {'addr_pct_cd': 25,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-06-16T00:00:00.000',
#   'cmplnt_fr_tm': '01:00:00',
#   'cmplnt_num': 731960181,
#   'cmplnt_to_dt': '2018-06-16T00:00:00.000',
#   'cmplnt_to_tm': '10:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.939920299, 40.805436606]},
#   'latitude': 40.805436606,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'OPPOSITE OF',
#   'longitude': -73.939920299,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-16T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1000883.0,
#   'y_coord_cd': 232722.0},
#  {'addr_pct_cd': 40,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-03-05T00:00:00.000',
#   'cmplnt_fr_tm': '03:45:00',
#   'cmplnt_num': 238612817,
#   'cmplnt_to_dt': '2018-03-05T00:00:00.000',
#   'cmplnt_to_tm': '04:03:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 347,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.924299287, 40.807197754]},
#   'latitude': 40.807197754,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.924299287,
#   'ofns_desc': 'INTOXICATED & IMPAIRED DRIVING',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 905.0,
#   'pd_desc': 'INTOXICATED DRIVING,ALCOHOL',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-03-05T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '45-64',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'E',
#   'x_coord_cd': 1005207.0,
#   'y_coord_cd': 233367.0},
#  {'addr_pct_cd': 107,
#   'boro_nm': 'QUEENS',
#   'cmplnt_fr_dt': '1997-01-06T00:00:00.000',
#   'cmplnt_fr_tm': '16:00:00',
#   'cmplnt_num': 314246092,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 112,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.760482912, 40.723892899]},
#   'latitude': 40.723892899,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.760482912,
#   'ofns_desc': 'THEFT-FRAUD',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO QUEENS SOUTH',
#   'pd_cd': 739.0,
#   'pd_desc': 'FRAUD,UNCLASSIFIED-FELONY',
#   'prem_typ_desc': 'RESIDENCE-HOUSE',
#   'rpt_dt': '2018-04-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1050640.0,
#   'y_coord_cd': 203098.0},
#  {'addr_pct_cd': 45,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-06-20T00:00:00.000',
#   'cmplnt_fr_tm': '14:30:00',
#   'cmplnt_num': 661464825,
#   'cmplnt_to_dt': '2018-06-20T00:00:00.000',
#   'cmplnt_to_tm': '14:40:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': 'THROGGS NECK',
#   'housing_psa': 939.0,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.821415888, 40.821584683]},
#   'latitude': 40.821584683,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'OPPOSITE OF',
#   'longitude': -73.821415888,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 254.0,
#   'pd_desc': 'MISCHIEF, CRIMINAL 4, OF MOTOR',
#   'prem_typ_desc': 'GROCERY/BODEGA',
#   'rpt_dt': '2018-06-20T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1033678.0,
#   'y_coord_cd': 238650.0},
#  {'addr_pct_cd': 75,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-06-01T00:00:00.000',
#   'cmplnt_fr_tm': '15:50:00',
#   'cmplnt_num': 288418243,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 344,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.873791979, 40.689420166]},
#   'latitude': 40.689420166,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.873791979,
#   'ofns_desc': 'ASSAULT 3 & RELATED OFFENSES',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 101.0,
#   'pd_desc': 'ASSAULT 3',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-01T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '<18',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '<18',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1019251.0,
#   'y_coord_cd': 190473.0},
#  {'addr_pct_cd': 44,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-03-03T00:00:00.000',
#   'cmplnt_fr_tm': '17:40:00',
#   'cmplnt_num': 995113038,
#   'cmplnt_to_dt': '2018-03-03T00:00:00.000',
#   'cmplnt_to_tm': '18:20:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 106,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.911108193, 40.841694933]},
#   'latitude': 40.841694933,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.911108193,
#   'ofns_desc': 'FELONY ASSAULT',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 109.0,
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-03-03T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '45-64',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1008846.0,
#   'y_coord_cd': 245939.0},
#  {'addr_pct_cd': 67,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-01-24T00:00:00.000',
#   'cmplnt_fr_tm': '22:25:00',
#   'cmplnt_num': 542853877,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 106,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.916295626, 40.648325678]},
#   'latitude': 40.648325678,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.916295626,
#   'ofns_desc': 'FELONY ASSAULT',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 109.0,
#   'pd_desc': 'ASSAULT 2,1,UNCLASSIFIED',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-01-24T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '65+',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1007478.0,
#   'y_coord_cd': 175487.0},
#  {'addr_pct_cd': 73,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-06-30T00:00:00.000',
#   'cmplnt_fr_tm': '20:50:00',
#   'cmplnt_num': 716919171,
#   'cmplnt_to_dt': '2018-06-30T00:00:00.000',
#   'cmplnt_to_tm': '20:55:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 110,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.909650986, 40.655931937]},
#   'latitude': 40.655931937,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.909650986,
#   'ofns_desc': 'GRAND LARCENY OF MOTOR VEHICLE',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 441.0,
#   'pd_desc': 'LARCENY,GRAND OF AUTO',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-30T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1009319.0,
#   'y_coord_cd': 178260.0},
#  {'addr_pct_cd': 41,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-05-04T00:00:00.000',
#   'cmplnt_fr_tm': '01:20:00',
#   'cmplnt_num': 203752720,
#   'cmplnt_to_dt': nan,
#   'cmplnt_to_tm': nan,
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 351,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.900845224, 40.81908109]},
#   'latitude': 40.81908109,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.900845224,
#   'ofns_desc': 'CRIMINAL MISCHIEF & RELATED OF',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 259.0,
#   'pd_desc': 'CRIMINAL MISCHIEF,UNCLASSIFIED 4',
#   'prem_typ_desc': 'RESIDENCE - APT. HOUSE',
#   'rpt_dt': '2018-05-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'BLACK',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'M',
#   'x_coord_cd': 1011695.0,
#   'y_coord_cd': 237703.0},
#  {'addr_pct_cd': 75,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-04-05T00:00:00.000',
#   'cmplnt_fr_tm': '01:40:00',
#   'cmplnt_num': 355175878,
#   'cmplnt_to_dt': '2018-04-05T00:00:00.000',
#   'cmplnt_to_tm': '02:10:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 352,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.887585787, 40.652286628]},
#   'latitude': 40.652286628,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.887585787,
#   'ofns_desc': 'CRIMINAL TRESPASS',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 203.0,
#   'pd_desc': 'TRESPASS 3, CRIMINAL',
#   'prem_typ_desc': 'HOTEL/MOTEL',
#   'rpt_dt': '2018-04-05T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 1015443.0,
#   'y_coord_cd': 176939.0},
#  {'addr_pct_cd': 61,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-05-01T00:00:00.000',
#   'cmplnt_fr_tm': '18:00:00',
#   'cmplnt_num': 541305085,
#   'cmplnt_to_dt': '2018-05-01T00:00:00.000',
#   'cmplnt_to_tm': '18:05:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point',
#    'coordinates': [-73.94326980700001, 40.605023855]},
#   'latitude': 40.605023855,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.943269807,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'LIQUOR STORE',
#   'rpt_dt': '2018-05-01T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': 'UNKNOWN',
#   'susp_race': 'WHITE',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 1000003.0,
#   'y_coord_cd': 159705.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-05-07T00:00:00.000',
#   'cmplnt_fr_tm': '03:00:00',
#   'cmplnt_num': 390837967,
#   'cmplnt_to_dt': '2018-05-07T00:00:00.000',
#   'cmplnt_to_tm': '03:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': 'STAPLETON',
#   'housing_psa': 1292.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 116,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.077483159, 40.644726131]},
#   'latitude': 40.644726131,
#   'law_cat_cd': 'FELONY',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -74.077483159,
#   'ofns_desc': 'SEX CRIMES',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 177.0,
#   'pd_desc': 'SEXUAL ABUSE',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-05-09T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '<18',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '<18',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 962748.0,
#   'y_coord_cd': 174174.0},
#  {'addr_pct_cd': 42,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-03-28T00:00:00.000',
#   'cmplnt_fr_tm': '12:00:00',
#   'cmplnt_num': 672505213,
#   'cmplnt_to_dt': '2018-03-28T00:00:00.000',
#   'cmplnt_to_tm': '12:05:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 233,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.911307169, 40.822569916]},
#   'latitude': 40.822569916,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.911307169,
#   'ofns_desc': 'SEX CRIMES',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 175.0,
#   'pd_desc': 'SEXUAL ABUSE 3,2',
#   'prem_typ_desc': 'PUBLIC SCHOOL',
#   'rpt_dt': '2018-03-28T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': nan,
#   'susp_race': nan,
#   'susp_sex': nan,
#   'transit_district': nan,
#   'vic_age_group': '<18',
#   'vic_race': 'BLACK HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 1008798.0,
#   'y_coord_cd': 238971.0},
#  {'addr_pct_cd': 88,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-03-04T00:00:00.000',
#   'cmplnt_fr_tm': '17:21:00',
#   'cmplnt_num': 725995141,
#   'cmplnt_to_dt': '2018-03-04T00:00:00.000',
#   'cmplnt_to_tm': '17:22:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': 'INGERSOLL',
#   'housing_psa': 477.0,
#   'juris_desc': 'N.Y. HOUSING POLICE',
#   'jurisdiction_code': 2.0,
#   'ky_cd': 352,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.982118597, 40.694219964]},
#   'latitude': 40.694219964,
#   'law_cat_cd': 'MISDEMEANOR',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.982118597,
#   'ofns_desc': 'CRIMINAL TRESPASS',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 205.0,
#   'pd_desc': 'TRESPASS 2, CRIMINAL',
#   'prem_typ_desc': 'RESIDENCE - PUBLIC HOUSING',
#   'rpt_dt': '2018-03-04T00:00:00.000',
#   'station_name': nan,
#   'susp_age_group': '45-64',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'UNKNOWN',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'E',
#   'x_coord_cd': 989209.0,
#   'y_coord_cd': 192197.0},
#  ...]

# %%
setlist_competance = set(list(map(lambda crime:crime['crm_atpt_cptd_cd'],crime_data)))
list_competance = list(map(lambda crime:crime['crm_atpt_cptd_cd'],crime_data))

# %%
def count_function_sorted_most_least(unique_list, full_list):
    CF=[]
    for list_item in unique_list:
        CF_dict = {}
        CF_dict['key'] = list_item
        CF_dict['count'] = full_list.count(list_item)
        CF.append(CF_dict)
    #return CF_dict
    return sorted(CF, key=lambda k:k['count'],reverse=True)

def data_query(data,dict_key):
    set_list = set(list(map(lambda crime:crime[str(dict_key)],data)))
    full_instance_list = list(map(lambda crime:crime[str(dict_key)],data))
    result = count_function_sorted_most_least(set_list,full_instance_list)
    return result

data_query(crime_data,'crm_atpt_cptd_cd')
# Out:
# [{'key': 'COMPLETED', 'count': 225082}, {'key': 'ATTEMPTED', 'count': 3823}]

# %%
compentance = count_function_sorted_most_least(setlist_competance, list_competance)

# %%
compentance
# Out:
# [{'status': 'COMPLETED', 'count': 225082},
#  {'status': 'ATTEMPTED', 'count': 3823}]

# %%
foo= list(list(map(lambda stat: stat.keys(),crime_data))[0])

# %%
'-' == '-'
# Out:
# True

# %%
crime_data[0]['rpt_dt'].replace('-','-')split('T', 1)[0]
# Out:
# '2018-06-07'

# %%
crime_data[1]
# Out:
# {'addr_pct_cd': 40,
#  'boro_nm': 'BRONX',
#  'cmplnt_fr_dt': '2018-06-16T00:00:00.000',
#  'cmplnt_fr_tm': '18:00:00',
#  'cmplnt_num': 740647006,
#  'cmplnt_to_dt': '2018-06-17T00:00:00.000',
#  'cmplnt_to_tm': '05:00:00',
#  'crm_atpt_cptd_cd': 'COMPLETED',
#  'hadevelopt': nan,
#  'housing_psa': nan,
#  'juris_desc': 'N.Y. POLICE DEPT',
#  'jurisdiction_code': 0.0,
#  'ky_cd': 109,
#  'lat_lon': {'type': 'Point', 'coordinates': [-73.916571116, 40.822837337]},
#  'latitude': 40.822837337,
#  'law_cat_cd': 'FELONY',
#  'loc_of_occur_desc': nan,
#  'longitude': -73.916571116,
#  'ofns_desc': 'GRAND LARCENY',
#  'parks_nm': nan,
#  'patrol_boro': 'PATROL BORO BRONX',
#  'pd_cd': 421.0,
#  'pd_desc': 'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#  'prem_typ_desc': 'STREET',
#  'rpt_dt': '2018-06-17T00:00:00.000',
#  'station_name': nan,
#  'susp_age_group': 'UNKNOWN',
#  'susp_race': 'UNKNOWN',
#  'susp_sex': 'U',
#  'transit_district': nan,
#  'vic_age_group': '45-64',
#  'vic_race': 'WHITE HISPANIC',
#  'vic_sex': 'M',
#  'x_coord_cd': 1007341.0,
#  'y_coord_cd': 239067.0}

# %%
def bad_ages_finder(data):
    vic_bad_values = list(set(list(map(lambda x: x['vic_age_group'],data))))
    susp_bad_values = list(set(list(map(lambda x: x['susp_age_group'],data))))
    all_age_values = set(vic_bad_values+susp_bad_values)
    bad_ages_1 = list(filter(lambda x:x!=('<18'),all_age_values))
    bad_ages_2 = list(filter(lambda x:x!=('18-24'),bad_ages_1))
    bad_ages_3 = list(filter(lambda x:x!=('25-44'),bad_ages_2))
    bad_ages_4 = list(filter(lambda x:x!=('45-64'),bad_ages_3))
    bad_ages = list(filter(lambda x:x!=('65+'),bad_ages_4))
    return bad_ages
bad_ages = set(bad_ages_finder(crime_data))
bad_ages
# Out:
# {'-2',
#  '-43',
#  '-5',
#  '-51',
#  '-55',
#  '-61',
#  '-63',
#  '-76',
#  '-940',
#  '-942',
#  '-955',
#  '-956',
#  '-958',
#  '-968',
#  '-972',
#  '-974',
#  '-978',
#  '1012',
#  '1017',
#  '1018',
#  '1967',
#  '2018',
#  '920',
#  '922',
#  '928',
#  '938',
#  '951',
#  '952',
#  '954',
#  '970',
#  '972',
#  'UNKNOWN',
#  nan}

# %%
def clean_susp_age(element,remove_list):
    for bad in remove_list:
        if element['susp_age_group'] == bad:

            return 'Not Available'
    return element['susp_age_group']
clean_susp_age(crime_data[1],bad_ages)
# Out:
# 'Not Available'

# %%
def clean_vic_age(element,remove_list):
    for bad in remove_list:
        if element['vic_age_group'] == bad:

            return 'Not Available'
    return element['vic_age_group']

# %%
def clean_crime_data_master(data):
    cleaned_data = data.copy()
    for x in cleaned_data:
        x['cmplnt_fr_dt'] = x['cmplnt_fr_dt'].split("T",1)[0]
        x['rpt_dt'] = x['rpt_dt'].split("T",1)[0]
        x['law_cat_cd'] = x['law_cat_cd'].title()
        x['susp_age_group'] = clean_susp_age(x,bad_ages_finder(cleaned_data))
        x['vic_age_group'] = clean_vic_age(x,bad_ages_finder(cleaned_data))
    return cleaned_data
crime_data_clean = clean_crime_data_master(crime_data[0:6])
test_crime_data_single = crime_data_clean[0]
crime_data_clean
# Out:
# [{'addr_pct_cd': 19,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-06-07',
#   'cmplnt_fr_tm': '13:20:00',
#   'cmplnt_num': 568680571,
#   'cmplnt_to_dt': '2018-06-07T00:00:00.000',
#   'cmplnt_to_tm': '13:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 105,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.955834874, 40.779163]},
#   'latitude': 40.779163,
#   'law_cat_cd': 'Felony',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.955834874,
#   'ofns_desc': 'ROBBERY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN NORTH',
#   'pd_cd': 384.0,
#   'pd_desc': 'ROBBERY,POCKETBOOK/CARRIED BAG',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-07',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'BLACK',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': '25-44',
#   'vic_race': 'BLACK',
#   'vic_sex': 'F',
#   'x_coord_cd': 996482.0,
#   'y_coord_cd': 223147.0},
#  {'addr_pct_cd': 40,
#   'boro_nm': 'BRONX',
#   'cmplnt_fr_dt': '2018-06-16',
#   'cmplnt_fr_tm': '18:00:00',
#   'cmplnt_num': 740647006,
#   'cmplnt_to_dt': '2018-06-17T00:00:00.000',
#   'cmplnt_to_tm': '05:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 109,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.916571116, 40.822837337]},
#   'latitude': 40.822837337,
#   'law_cat_cd': 'Felony',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.916571116,
#   'ofns_desc': 'GRAND LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BRONX',
#   'pd_cd': 421.0,
#   'pd_desc': 'LARCENY,GRAND FROM VEHICLE/MOTORCYCLE',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-06-17',
#   'station_name': nan,
#   'susp_age_group': 'Not Available',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '45-64',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'M',
#   'x_coord_cd': 1007341.0,
#   'y_coord_cd': 239067.0},
#  {'addr_pct_cd': 6,
#   'boro_nm': 'MANHATTAN',
#   'cmplnt_fr_dt': '2018-04-23',
#   'cmplnt_fr_tm': '15:20:00',
#   'cmplnt_num': 966432005,
#   'cmplnt_to_dt': '2018-04-23T00:00:00.000',
#   'cmplnt_to_tm': '15:30:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.993870805, 40.735667088]},
#   'latitude': 40.735667088,
#   'law_cat_cd': 'Misdemeanor',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -73.993870805,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO MAN SOUTH',
#   'pd_cd': 338.0,
#   'pd_desc': 'LARCENY,PETIT FROM BUILDING,UN',
#   'prem_typ_desc': 'DRUG STORE',
#   'rpt_dt': '2018-04-23',
#   'station_name': nan,
#   'susp_age_group': 'Not Available',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': '18-24',
#   'vic_race': 'WHITE HISPANIC',
#   'vic_sex': 'F',
#   'x_coord_cd': 985949.0,
#   'y_coord_cd': 207297.0},
#  {'addr_pct_cd': 78,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-05',
#   'cmplnt_fr_tm': '19:50:00',
#   'cmplnt_num': 619611663,
#   'cmplnt_to_dt': '2018-02-05T00:00:00.000',
#   'cmplnt_to_tm': '20:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.97775121, 40.684461543]},
#   'latitude': 40.684461543,
#   'law_cat_cd': 'Misdemeanor',
#   'loc_of_occur_desc': 'FRONT OF',
#   'longitude': -73.97775121,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN SOUTH',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'CHAIN STORE',
#   'rpt_dt': '2018-02-05',
#   'station_name': nan,
#   'susp_age_group': '18-24',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'M',
#   'transit_district': nan,
#   'vic_age_group': 'Not Available',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 990421.0,
#   'y_coord_cd': 188642.0},
#  {'addr_pct_cd': 90,
#   'boro_nm': 'BROOKLYN',
#   'cmplnt_fr_dt': '2018-02-16',
#   'cmplnt_fr_tm': '13:30:00',
#   'cmplnt_num': 703493598,
#   'cmplnt_to_dt': '2018-02-17T00:00:00.000',
#   'cmplnt_to_tm': '20:00:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 107,
#   'lat_lon': {'type': 'Point', 'coordinates': [-73.958154327, 40.708050116]},
#   'latitude': 40.708050116,
#   'law_cat_cd': 'Felony',
#   'loc_of_occur_desc': nan,
#   'longitude': -73.958154327,
#   'ofns_desc': 'BURGLARY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO BKLYN NORTH',
#   'pd_cd': 234.0,
#   'pd_desc': 'BURGLARY,UNKNOWN TIME',
#   'prem_typ_desc': 'STREET',
#   'rpt_dt': '2018-02-18',
#   'station_name': nan,
#   'susp_age_group': 'Not Available',
#   'susp_race': 'UNKNOWN',
#   'susp_sex': 'U',
#   'transit_district': nan,
#   'vic_age_group': 'Not Available',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 995852.0,
#   'y_coord_cd': 197238.0},
#  {'addr_pct_cd': 120,
#   'boro_nm': 'STATEN ISLAND',
#   'cmplnt_fr_dt': '2018-04-14',
#   'cmplnt_fr_tm': '20:40:00',
#   'cmplnt_num': 840976601,
#   'cmplnt_to_dt': '2018-04-14T00:00:00.000',
#   'cmplnt_to_tm': '20:51:00',
#   'crm_atpt_cptd_cd': 'COMPLETED',
#   'hadevelopt': nan,
#   'housing_psa': nan,
#   'juris_desc': 'N.Y. POLICE DEPT',
#   'jurisdiction_code': 0.0,
#   'ky_cd': 341,
#   'lat_lon': {'type': 'Point', 'coordinates': [-74.087471423, 40.638812184]},
#   'latitude': 40.638812184,
#   'law_cat_cd': 'Misdemeanor',
#   'loc_of_occur_desc': 'INSIDE',
#   'longitude': -74.087471423,
#   'ofns_desc': 'PETIT LARCENY',
#   'parks_nm': nan,
#   'patrol_boro': 'PATROL BORO STATEN ISLAND',
#   'pd_cd': 333.0,
#   'pd_desc': 'LARCENY,PETIT FROM STORE-SHOPL',
#   'prem_typ_desc': 'CHAIN STORE',
#   'rpt_dt': '2018-04-14',
#   'station_name': nan,
#   'susp_age_group': '25-44',
#   'susp_race': 'WHITE HISPANIC',
#   'susp_sex': 'F',
#   'transit_district': nan,
#   'vic_age_group': 'Not Available',
#   'vic_race': 'UNKNOWN',
#   'vic_sex': 'D',
#   'x_coord_cd': 959974.0,
#   'y_coord_cd': 172022.0}]

# %%
# def clean_crime_data_master(data):
#     clean_date_of_occurance = list(map(lambda event:event['rpt_dt'].split('T', 1)[0],data))


# #     clean_law_cat = list(map(lambda event:event['law_cat_cd'].title(),clean_report_date))
# #     clean_both_age_groups = list(map(lambda event:clean_age_groups(event,bad_ages_finder(data)),clean_law_cat))
# #     return clean_both_age_groups
#     return clean_date_of_occurance
# clean_crime_data_master(crime_data)

# %%
# def clean_age_group(data,remove_list):
#     Ori_data = data.copy()
#     for bad in remove_list:
#         if Ori_data['susp_age_group'] == bad:
#             Ori_data['susp_age_group'] = 'Not Available'
#     for bad in remove_list:
#         if Ori_data['vic_age_group'] == bad:
#             Ori_data['vic_age_group'] = 'Not Available'      
#     return Ori_data
            
# clean_age_groups(crime_data[1],bad_ages)

# %%
data_query(crime_data,'precinct')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-370482d31a72> in <module>()
# ----> 1 data_query(crime_data,'precinct')
#
# <ipython-input-4-e3d7d23c9266> in data_query(data, dict_key)
#      10
#      11 def data_query(data,dict_key):
# ---> 12     set_list = set(list(map(lambda crime:crime[str(dict_key)],data)))
#      13     full_instance_list = list(map(lambda crime:crime[str(dict_key)],data))
#      14     result = count_function_sorted_most_least(set_list,full_instance_list)
#
# <ipython-input-4-e3d7d23c9266> in <lambda>(crime)
#      10
#      11 def data_query(data,dict_key):
# ---> 12     set_list = set(list(map(lambda crime:crime[str(dict_key)],data)))
#      13     full_instance_list = list(map(lambda crime:crime[str(dict_key)],data))
#      14     result = count_function_sorted_most_least(set_list,full_instance_list)
#
# KeyError: 'precinct'

# %%
from sqlalchemy import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship

Base = declarative_base()


class Crime_Event(Base): #parent
    __tablename__ = 'crime_events'
    id=Column(Integer,primary_key=True)
    complaint_num=Column(Integer)
    precinct=Column(Text)
    date_of_occurance=Column(Date)
    time_of_occurance=Column(String)
    crime_completed_y_n=Column(Text)
    jurisdiction_code=Column(Text)
    jurisdiction_desc=Column(Text)
    report_date=Column(Date)
    level_of_offense=Column(Text)
    offense_descr=Column(Text)
    location_id = Column(Integer,ForeignKey('locations.id'))
    victim_id = Column(Integer,ForeignKey('victims.id'))
    suspect_id = Column(Integer,ForeignKey('suspects.id'))

    locations = relationship("Location",back_populates="crimes")
    victims = relationship("Victim",back_populates="crimes")
    suspects = relationship("Suspect",back_populates="crimes")

class Location(Base):
    __tablename__ = 'locations'
    id=Column(Integer,primary_key=True)
    latitude=Column(Float)
    longitude=Column(Float)
    # crime_id = Column(Integer, ForeignKey('crime_events.id'))

    crimes = relationship("Crime_Event",back_populates="locations")


class Victim(Base): #child
    __tablename__ = 'victims'
    id=Column(Integer,primary_key=True)
    age_group = Column(Text)
    race = Column(Text)
    gender = Column(Text)
    # crime_id = Column(Integer, ForeignKey('crime_events.id'))

    crimes = relationship("Crime_Event",back_populates="victims")


class Suspect(Base):
    __tablename__ = 'suspects'
    id=Column(Integer,primary_key=True)
    age_group = Column(Text)
    race = Column(Text)
    gender = Column(Text)
    # crime_id = Column(Integer, ForeignKey('crime_events.id'))

    crimes = relationship("Crime_Event",back_populates="suspects")


# engine = create_engine('sqlite:///crime_data.db')
# Base.metadata.create_all(engine)

# %%
crime_1 = Crime_Event(precinct="ABC")

# %%
crime_1.precinct
# Out:
# 'ABC'

# %%
def convert_to_classes(element):
    crime_event = Crime_Event(complaint_num=element['cmplnt_num'],precinct=element['addr_pct_cd'],date_of_occurance=element['cmplnt_fr_dt'],time_of_occurance=element['cmplnt_fr_tm'],crime_completed_y_n=element['crm_atpt_cptd_cd'],jurisdiction_code=element['jurisdiction_code'],jurisdiction_desc=element['juris_desc'],report_date=element['rpt_dt'],level_of_offense=element['law_cat_cd'],offense_descr=element['ofns_desc'],locations=Location(latitude=element['latitude'],longitude=element['longitude']),suspects = Suspect(age_group=element['susp_age_group'],race=element['susp_race'],gender=element['susp_sex']),victims = Victim(age_group=element['vic_age_group'],race=element['vic_race'],gender=element['vic_sex']))
    return crime_event

# %%
test_data =  
print(test_data[3].precinct)
print(test_data[3].victims.age_group)
# Out:
# 78
# Not Available

# %%
convert_to_classes(crime_data_clean[1])
# crime_data_clean[1]

# %%
crime_event_objects = list(map(lambda event:convert_to_classes(event),crime_data_clean))
crime_event_objects[0].victims.age_group
# Out:
# '25-44'

# %%
data_query(crime_data,'addr_pct_cd')
# Out:
# [{'key': 75, 'count': 7393},
#  {'key': 44, 'count': 5991},
#  {'key': 40, 'count': 5801},
#  {'key': 14, 'count': 5288},
#  {'key': 43, 'count': 5030},
#  {'key': 52, 'count': 4904},
#  {'key': 47, 'count': 4864},
#  {'key': 67, 'count': 4859},
#  {'key': 73, 'count': 4750},
#  {'key': 46, 'count': 4473},
#  {'key': 109, 'count': 4202},
#  {'key': 18, 'count': 4166},
#  {'key': 115, 'count': 4015},
#  {'key': 114, 'count': 4006},
#  {'key': 42, 'count': 4000},
#  {'key': 48, 'count': 3871},
#  {'key': 120, 'count': 3790},
#  {'key': 79, 'count': 3783},
#  {'key': 113, 'count': 3578},
#  {'key': 13, 'count': 3479},
#  {'key': 70, 'count': 3343},
#  {'key': 1, 'count': 3337},
#  {'key': 105, 'count': 3330},
#  {'key': 49, 'count': 3262},
#  {'key': 110, 'count': 3259},
#  {'key': 90, 'count': 3247},
#  {'key': 103, 'count': 3219},
#  {'key': 25, 'count': 3170},
#  {'key': 83, 'count': 3154},
#  {'key': 19, 'count': 3147},
#  {'key': 77, 'count': 3079},
#  {'key': 41, 'count': 3065},
#  {'key': 23, 'count': 2998},
#  {'key': 45, 'count': 2978},
#  {'key': 71, 'count': 2976},
#  {'key': 121, 'count': 2892},
#  {'key': 60, 'count': 2871},
#  {'key': 104, 'count': 2819},
#  {'key': 32, 'count': 2818},
#  {'key': 106, 'count': 2800},
#  {'key': 61, 'count': 2746},
#  {'key': 28, 'count': 2722},
#  {'key': 34, 'count': 2658},
#  {'key': 72, 'count': 2606},
#  {'key': 84, 'count': 2598},
#  {'key': 9, 'count': 2484},
#  {'key': 102, 'count': 2470},
#  {'key': 81, 'count': 2455},
#  {'key': 24, 'count': 2444},
#  {'key': 62, 'count': 2414},
#  {'key': 6, 'count': 2384},
#  {'key': 122, 'count': 2362},
#  {'key': 108, 'count': 2318},
#  {'key': 101, 'count': 2201},
#  {'key': 68, 'count': 2194},
#  {'key': 107, 'count': 2146},
#  {'key': 5, 'count': 2130},
#  {'key': 20, 'count': 2111},
#  {'key': 69, 'count': 2092},
#  {'key': 63, 'count': 2064},
#  {'key': 78, 'count': 2035},
#  {'key': 7, 'count': 1994},
#  {'key': 17, 'count': 1982},
#  {'key': 50, 'count': 1969},
#  {'key': 66, 'count': 1955},
#  {'key': 33, 'count': 1929},
#  {'key': 10, 'count': 1914},
#  {'key': 94, 'count': 1854},
#  {'key': 30, 'count': 1853},
#  {'key': 88, 'count': 1784},
#  {'key': 112, 'count': 1553},
#  {'key': 26, 'count': 1544},
#  {'key': 76, 'count': 1291},
#  {'key': 123, 'count': 1244},
#  {'key': 111, 'count': 1168},
#  {'key': 100, 'count': 1125},
#  {'key': 22, 'count': 105}]
